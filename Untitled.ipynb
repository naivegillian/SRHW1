# %%
'''
import zipfile
with zipfile.ZipFile("hw1__data.zip","r") as zip_ref:
    zip_ref.extractall("nwhw1_data")
'''

# %%
import os
Task_name = 'nwhw1_data/hw1_data/Synthetic/5000'
data_root = "/home/p88101029/"
raw_data_base = os.path.join(data_root,Task_name)
os.makedirs(raw_data_base, exist_ok=True)

# %%
listoffolder=sorted(os.listdir(raw_data_base), reverse=False)

# %%
listoffolder
# Out:
# ['0.txt',
#  '0_score.txt',
#  '1.txt',
#  '10.txt',
#  '10_score.txt',
#  '11.txt',
#  '11_score.txt',
#  '12.txt',
#  '12_score.txt',
#  '13.txt',
#  '13_score.txt',
#  '14.txt',
#  '14_score.txt',
#  '15.txt',
#  '15_score.txt',
#  '16.txt',
#  '16_score.txt',
#  '17.txt',
#  '17_score.txt',
#  '18.txt',
#  '18_score.txt',
#  '19.txt',
#  '19_score.txt',
#  '1_score.txt',
#  '2.txt',
#  '20.txt',
#  '20_score.txt',
#  '21.txt',
#  '21_score.txt',
#  '22.txt',
#  '22_score.txt',
#  '23.txt',
#  '23_score.txt',
#  '24.txt',
#  '24_score.txt',
#  '25.txt',
#  '25_score.txt',
#  '26.txt',
#  '26_score.txt',
#  '27.txt',
#  '27_score.txt',
#  '28.txt',
#  '28_score.txt',
#  '29.txt',
#  '29_score.txt',
#  '2_score.txt',
#  '3.txt',
#  '3_score.txt',
#  '4.txt',
#  '4_score.txt',
#  '5.txt',
#  '5_score.txt',
#  '6.txt',
#  '6_score.txt',
#  '7.txt',
#  '7_score.txt',
#  '8.txt',
#  '8_score.txt',
#  '9.txt',
#  '9_score.txt']

# %%
# !git clone https://github.com/FFrankyy/DrBC.git
# Out:
# Cloning into 'DrBC'...
# remote: Enumerating objects: 242, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 242 (delta 0), reused 0 (delta 0), pack-reused 239
# Receiving objects: 100% (242/242), 8.80 MiB | 13.49 MiB/s, done.
# Resolving deltas: 100% (111/111), done.
# Defaulting to user installation because normal site-packages is not writeable
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
cd DrBC
# Out:
# /home/p88101029/DrBC

# %%
# !pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting Cython
#   Downloading Cython-0.29.33-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 2.0 MB/s
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 2)) (2.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 3)) (1.5.4)
# Requirement already satisfied: numpy in /home/p88101029/.local/lib/python3.6/site-packages (from -r requirements.txt (line 4)) (1.19.5)
# Requirement already satisfied: pandas in /home/p88101029/.local/lib/python3.6/site-packages (from -r requirements.txt (line 5)) (1.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from -r requirements.txt (line 6)) (4.54.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->-r requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/lib/python3/dist-packages (from pandas->-r requirements.txt (line 5)) (2018.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->-r requirements.txt (line 5)) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->-r requirements.txt (line 5)) (1.15.0)
# Installing collected packages: Cython
#   WARNING: The scripts cygdb, cython and cythonize are installed in '/home/p88101029/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed Cython-0.29.33

# %%
# !ls
# Out:
# BetLearn.py	  LICENSE		 PrepareBatchGraph.pyx	start.py
# graph.pxd	  metrics.pxd		 README.md		utils.pxd
# graph.pyx	  metrics.pyx		 requirements.txt	utils.pyx
# graph_struct.pxd  models		 setup.py		visualize
# graph_struct.pyx  PrepareBatchGraph.pxd  src

# %%
import numpy as np
pairedge=[]
with open('/home/p88101029/nwhw1_data/hw1_data/Synthetic/5000/0.txt', 'r') as f:
    for line in f.readlines():
        pairedge.append(list(map(int,line.split())))
score=[]        
with open('/home/p88101029/nwhw1_data/hw1_data/Synthetic/5000/0_score.txt', 'r') as f:
    for line in f.readlines():
        score.append([int(line.split()[0]),float(line.split()[1])])

# %%
import torch
from torch_geometric.data import Data
from torch_geometric.utils import to_undirected
edge_index = torch.tensor(pairedge).t().contiguous()
edge_index = to_undirected(edge_index)
y = torch.tensor([y[1] for y in score], dtype=torch.float)
x = torch.eye(5000,5000)
mask = torch.tensor(np.random.choice(a=[True, False], size=(5000), p=[0.9, 0.1]))
data = Data(x=x,y=y,edge_index=edge_index,train_mask=mask)

# %%
data.edge_index
# Out:
# tensor([[   0,    0,    0,  ..., 4999, 4999, 4999],
#         [   4,    5,    8,  ..., 1078, 1433, 3132]])

# %%
import torch
from torch.nn import Linear
from torch_geometric.nn import GCNConv


class GCN(torch.nn.Module):
    def __init__(self):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        self.conv1 = GCNConv(5000, 4)
        self.conv2 = GCNConv(4, 4)
        self.conv3 = GCNConv(4, 2)
        self.classifier = Linear(2, 1)

    def forward(self, x, edge_index):
        h = self.conv1(x, edge_index)
        h = h.tanh()
        h = self.conv2(h, edge_index)
        h = h.tanh()
        h = self.conv3(h, edge_index)
        h = h.tanh()  # Final GNN embedding space.
        
        # Apply a final (linear) classifier.
        out = self.classifier(h)

        return out, h

model = GCN()
model.to(device)
# Out:
# GCN(
#   (conv1): GCNConv(5000, 4)
#   (conv2): GCNConv(4, 4)
#   (conv3): GCNConv(4, 2)
#   (classifier): Linear(in_features=2, out_features=1, bias=True)
# )

# %%
criterion = torch.nn.MSELoss()  # Define loss criterion.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)  # Define optimizer.

def train(data):
    optimizer.zero_grad()  # Clear gradients.
    out, h = model(data.x, data.edge_index)  # Perform a single forward pass.
    print(out[data.train_mask])
    print(out[data.train_mask].shape)
    loss = criterion(out[data.train_mask], data.y[data.train_mask])  # Compute the loss solely based on the training nodes.
    print(out[data.train_mask].requires_grad)
    print(out[data.train_mask].shape)
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.

    # Calculate training accuracy on our four examples
    predicted= out[~data.train_mask]
    target= data.y[~data.train_mask]
    vloss=criterion(predicted, target)
    
    return loss, h, vloss

for epoch in range(350):
    data = data.to('cuda:0')
    loss, h, vloss= train(data)
    if epoch % 10 == 0:
        print(loss,vloss)
# Out:
# tensor([[-0.5891],
#         [-0.5908],
#         [-0.5915],
#         ...,
#         [-0.5939],
#         [-0.5923],
#         [-0.5902]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.3498, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.3499, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[-0.3268],
#         [-0.3472],
#         [-0.4018],
#         ...,
#         [-0.5243],
#         [-0.5297],
#         [-0.5276]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0640],
#         [-0.1004],
#         [-0.2048],
#         ...,
#         [-0.4504],
#         [-0.4632],
#         [-0.4612]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.1791],
#         [ 0.1327],
#         [-0.0085],
#         ...,
#         [-0.3719],
#         [-0.3929],
#         [-0.3912]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3845],
#         [ 0.3356],
#         [ 0.1758],
#         ...,
#         [-0.2896],
#         [-0.3200],
#         [-0.3186]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5455],
#         [ 0.5002],
#         [ 0.3396],
#         ...,
#         [-0.2053],
#         [-0.2460],
#         [-0.2449]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6652],
#         [ 0.6268],
#         [ 0.4779],
#         ...,
#         [-0.1213],
#         [-0.1726],
#         [-0.1721]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.7513],
#         [ 0.7204],
#         [ 0.5892],
#         ...,
#         [-0.0408],
#         [-0.1027],
#         [-0.1027]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.8111],
#         [ 0.7866],
#         [ 0.6735],
#         ...,
#         [ 0.0314],
#         [-0.0400],
#         [-0.0405]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8491],
#         [0.8292],
#         [0.7311],
#         ...,
#         [0.0897],
#         [0.0108],
#         [0.0096]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8691],
#         [0.8523],
#         [0.7645],
#         ...,
#         [0.1304],
#         [0.0462],
#         [0.0445]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0392, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0375, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[0.8760],
#         [0.8608],
#         [0.7790],
#         ...,
#         [0.1538],
#         [0.0667],
#         [0.0645]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8736],
#         [0.8591],
#         [0.7799],
#         ...,
#         [0.1626],
#         [0.0744],
#         [0.0718]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8645],
#         [0.8500],
#         [0.7708],
#         ...,
#         [0.1600],
#         [0.0721],
#         [0.0692]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8503],
#         [0.8353],
#         [0.7541],
#         ...,
#         [0.1485],
#         [0.0620],
#         [0.0589]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8321],
#         [0.8162],
#         [0.7314],
#         ...,
#         [0.1306],
#         [0.0463],
#         [0.0429]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[0.8106],
#         [0.7934],
#         [0.7040],
#         ...,
#         [0.1080],
#         [0.0265],
#         [0.0231]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[7.8646e-01],
#         [7.6778e-01],
#         [6.7284e-01],
#         ...,
#         [8.2571e-02],
#         [4.1900e-03],
#         [6.8009e-04]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.7603],
#         [ 0.7399],
#         [ 0.6391],
#         ...,
#         [ 0.0557],
#         [-0.0193],
#         [-0.0229]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.7328],
#         [ 0.7106],
#         [ 0.6038],
#         ...,
#         [ 0.0287],
#         [-0.0430],
#         [-0.0466]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.7047],
#         [ 0.6807],
#         [ 0.5682],
#         ...,
#         [ 0.0026],
#         [-0.0657],
#         [-0.0693]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0120, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0123, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.6770],
#         [ 0.6512],
#         [ 0.5336],
#         ...,
#         [-0.0216],
#         [-0.0868],
#         [-0.0905]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6505],
#         [ 0.6231],
#         [ 0.5011],
#         ...,
#         [-0.0433],
#         [-0.1057],
#         [-0.1093]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6261],
#         [ 0.5975],
#         [ 0.4720],
#         ...,
#         [-0.0618],
#         [-0.1217],
#         [-0.1254]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6049],
#         [ 0.5752],
#         [ 0.4470],
#         ...,
#         [-0.0769],
#         [-0.1347],
#         [-0.1383]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5874],
#         [ 0.5569],
#         [ 0.4271],
#         ...,
#         [-0.0883],
#         [-0.1444],
#         [-0.1480]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5742],
#         [ 0.5433],
#         [ 0.4124],
#         ...,
#         [-0.0961],
#         [-0.1509],
#         [-0.1545]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5655],
#         [ 0.5343],
#         [ 0.4031],
#         ...,
#         [-0.1003],
#         [-0.1542],
#         [-0.1578]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5611],
#         [ 0.5299],
#         [ 0.3990],
#         ...,
#         [-0.1013],
#         [-0.1546],
#         [-0.1582]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5607],
#         [ 0.5297],
#         [ 0.3996],
#         ...,
#         [-0.0993],
#         [-0.1522],
#         [-0.1558]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5637],
#         [ 0.5332],
#         [ 0.4043],
#         ...,
#         [-0.0946],
#         [-0.1476],
#         [-0.1512]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0149, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0161, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5696],
#         [ 0.5396],
#         [ 0.4123],
#         ...,
#         [-0.0878],
#         [-0.1410],
#         [-0.1445]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5775],
#         [ 0.5482],
#         [ 0.4229],
#         ...,
#         [-0.0793],
#         [-0.1328],
#         [-0.1363]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5869],
#         [ 0.5583],
#         [ 0.4352],
#         ...,
#         [-0.0695],
#         [-0.1235],
#         [-0.1270]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5971],
#         [ 0.5693],
#         [ 0.4484],
#         ...,
#         [-0.0589],
#         [-0.1134],
#         [-0.1169]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6074],
#         [ 0.5804],
#         [ 0.4619],
#         ...,
#         [-0.0480],
#         [-0.1031],
#         [-0.1066]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6174],
#         [ 0.5912],
#         [ 0.4751],
#         ...,
#         [-0.0372],
#         [-0.0929],
#         [-0.0963]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6266],
#         [ 0.6011],
#         [ 0.4873],
#         ...,
#         [-0.0269],
#         [-0.0831],
#         [-0.0865]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6347],
#         [ 0.6099],
#         [ 0.4982],
#         ...,
#         [-0.0174],
#         [-0.0741],
#         [-0.0775]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6414],
#         [ 0.6173],
#         [ 0.5074],
#         ...,
#         [-0.0092],
#         [-0.0661],
#         [-0.0695]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6466],
#         [ 0.6229],
#         [ 0.5146],
#         ...,
#         [-0.0023],
#         [-0.0595],
#         [-0.0628]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0094, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0098, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.6501],
#         [ 0.6268],
#         [ 0.5196],
#         ...,
#         [ 0.0029],
#         [-0.0543],
#         [-0.0576]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6519],
#         [ 0.6288],
#         [ 0.5225],
#         ...,
#         [ 0.0065],
#         [-0.0506],
#         [-0.0539]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6520],
#         [ 0.6290],
#         [ 0.5232],
#         ...,
#         [ 0.0085],
#         [-0.0484],
#         [-0.0517]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6504],
#         [ 0.6274],
#         [ 0.5218],
#         ...,
#         [ 0.0088],
#         [-0.0477],
#         [-0.0509]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6474],
#         [ 0.6243],
#         [ 0.5185],
#         ...,
#         [ 0.0076],
#         [-0.0484],
#         [-0.0515]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6430],
#         [ 0.6197],
#         [ 0.5135],
#         ...,
#         [ 0.0052],
#         [-0.0502],
#         [-0.0533]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6374],
#         [ 0.6139],
#         [ 0.5071],
#         ...,
#         [ 0.0017],
#         [-0.0530],
#         [-0.0561]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6309],
#         [ 0.6071],
#         [ 0.4996],
#         ...,
#         [-0.0026],
#         [-0.0565],
#         [-0.0595]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6238],
#         [ 0.5997],
#         [ 0.4913],
#         ...,
#         [-0.0074],
#         [-0.0605],
#         [-0.0635]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6164],
#         [ 0.5918],
#         [ 0.4826],
#         ...,
#         [-0.0125],
#         [-0.0648],
#         [-0.0677]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0082, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0087, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.6088],
#         [ 0.5839],
#         [ 0.4737],
#         ...,
#         [-0.0176],
#         [-0.0691],
#         [-0.0720]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.6013],
#         [ 0.5761],
#         [ 0.4651],
#         ...,
#         [-0.0225],
#         [-0.0732],
#         [-0.0760]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5942],
#         [ 0.5686],
#         [ 0.4569],
#         ...,
#         [-0.0271],
#         [-0.0769],
#         [-0.0797]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5877],
#         [ 0.5618],
#         [ 0.4495],
#         ...,
#         [-0.0310],
#         [-0.0802],
#         [-0.0829]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5819],
#         [ 0.5558],
#         [ 0.4430],
#         ...,
#         [-0.0343],
#         [-0.0829],
#         [-0.0856]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5770],
#         [ 0.5507],
#         [ 0.4375],
#         ...,
#         [-0.0369],
#         [-0.0848],
#         [-0.0875]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5731],
#         [ 0.5466],
#         [ 0.4331],
#         ...,
#         [-0.0386],
#         [-0.0861],
#         [-0.0887]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5701],
#         [ 0.5435],
#         [ 0.4299],
#         ...,
#         [-0.0396],
#         [-0.0866],
#         [-0.0892]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5681],
#         [ 0.5414],
#         [ 0.4278],
#         ...,
#         [-0.0398],
#         [-0.0865],
#         [-0.0890]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5669],
#         [ 0.5403],
#         [ 0.4267],
#         ...,
#         [-0.0392],
#         [-0.0857],
#         [-0.0882]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0075, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0083, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5666],
#         [ 0.5399],
#         [ 0.4265],
#         ...,
#         [-0.0381],
#         [-0.0843],
#         [-0.0868]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5669],
#         [ 0.5403],
#         [ 0.4271],
#         ...,
#         [-0.0364],
#         [-0.0825],
#         [-0.0850]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5677],
#         [ 0.5412],
#         [ 0.4282],
#         ...,
#         [-0.0344],
#         [-0.0803],
#         [-0.0827]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5689],
#         [ 0.5424],
#         [ 0.4298],
#         ...,
#         [-0.0320],
#         [-0.0778],
#         [-0.0803]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5703],
#         [ 0.5439],
#         [ 0.4316],
#         ...,
#         [-0.0295],
#         [-0.0753],
#         [-0.0777]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5717],
#         [ 0.5455],
#         [ 0.4335],
#         ...,
#         [-0.0270],
#         [-0.0727],
#         [-0.0750]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5731],
#         [ 0.5469],
#         [ 0.4352],
#         ...,
#         [-0.0246],
#         [-0.0701],
#         [-0.0725]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5742],
#         [ 0.5481],
#         [ 0.4367],
#         ...,
#         [-0.0223],
#         [-0.0678],
#         [-0.0701]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5750],
#         [ 0.5489],
#         [ 0.4378],
#         ...,
#         [-0.0203],
#         [-0.0656],
#         [-0.0680]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5754],
#         [ 0.5493],
#         [ 0.4384],
#         ...,
#         [-0.0187],
#         [-0.0638],
#         [-0.0661]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0072, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5753],
#         [ 0.5493],
#         [ 0.4384],
#         ...,
#         [-0.0174],
#         [-0.0624],
#         [-0.0646]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5747],
#         [ 0.5487],
#         [ 0.4379],
#         ...,
#         [-0.0165],
#         [-0.0613],
#         [-0.0635]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5737],
#         [ 0.5476],
#         [ 0.4368],
#         ...,
#         [-0.0161],
#         [-0.0605],
#         [-0.0628]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5721],
#         [ 0.5459],
#         [ 0.4351],
#         ...,
#         [-0.0160],
#         [-0.0602],
#         [-0.0623]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5701],
#         [ 0.5438],
#         [ 0.4329],
#         ...,
#         [-0.0163],
#         [-0.0601],
#         [-0.0623]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5677],
#         [ 0.5413],
#         [ 0.4302],
#         ...,
#         [-0.0169],
#         [-0.0603],
#         [-0.0624]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5650],
#         [ 0.5385],
#         [ 0.4272],
#         ...,
#         [-0.0177],
#         [-0.0608],
#         [-0.0628]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5620],
#         [ 0.5354],
#         [ 0.4240],
#         ...,
#         [-0.0187],
#         [-0.0614],
#         [-0.0634]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5589],
#         [ 0.5322],
#         [ 0.4205],
#         ...,
#         [-0.0197],
#         [-0.0620],
#         [-0.0641]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5557],
#         [ 0.5288],
#         [ 0.4170],
#         ...,
#         [-0.0209],
#         [-0.0628],
#         [-0.0648]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0059, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0066, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5525],
#         [ 0.5255],
#         [ 0.4135],
#         ...,
#         [-0.0220],
#         [-0.0635],
#         [-0.0654]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5494],
#         [ 0.5223],
#         [ 0.4101],
#         ...,
#         [-0.0230],
#         [-0.0641],
#         [-0.0660]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5465],
#         [ 0.5192],
#         [ 0.4069],
#         ...,
#         [-0.0239],
#         [-0.0646],
#         [-0.0665]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5437],
#         [ 0.5163],
#         [ 0.4039],
#         ...,
#         [-0.0246],
#         [-0.0650],
#         [-0.0668]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5412],
#         [ 0.5137],
#         [ 0.4012],
#         ...,
#         [-0.0252],
#         [-0.0652],
#         [-0.0670]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5389],
#         [ 0.5114],
#         [ 0.3988],
#         ...,
#         [-0.0255],
#         [-0.0652],
#         [-0.0670]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5369],
#         [ 0.5093],
#         [ 0.3967],
#         ...,
#         [-0.0256],
#         [-0.0650],
#         [-0.0668]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5352],
#         [ 0.5075],
#         [ 0.3948],
#         ...,
#         [-0.0256],
#         [-0.0647],
#         [-0.0664]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5337],
#         [ 0.5060],
#         [ 0.3933],
#         ...,
#         [-0.0253],
#         [-0.0642],
#         [-0.0659]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5324],
#         [ 0.5046],
#         [ 0.3919],
#         ...,
#         [-0.0249],
#         [-0.0635],
#         [-0.0652]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0060, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5313],
#         [ 0.5035],
#         [ 0.3908],
#         ...,
#         [-0.0244],
#         [-0.0627],
#         [-0.0644]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5304],
#         [ 0.5024],
#         [ 0.3898],
#         ...,
#         [-0.0238],
#         [-0.0619],
#         [-0.0635]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5295],
#         [ 0.5015],
#         [ 0.3889],
#         ...,
#         [-0.0231],
#         [-0.0610],
#         [-0.0626]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5286],
#         [ 0.5006],
#         [ 0.3880],
#         ...,
#         [-0.0224],
#         [-0.0601],
#         [-0.0617]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5277],
#         [ 0.4996],
#         [ 0.3871],
#         ...,
#         [-0.0217],
#         [-0.0592],
#         [-0.0607]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5267],
#         [ 0.4986],
#         [ 0.3861],
#         ...,
#         [-0.0211],
#         [-0.0583],
#         [-0.0598]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5257],
#         [ 0.4975],
#         [ 0.3850],
#         ...,
#         [-0.0205],
#         [-0.0575],
#         [-0.0590]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5245],
#         [ 0.4963],
#         [ 0.3838],
#         ...,
#         [-0.0200],
#         [-0.0568],
#         [-0.0582]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5232],
#         [ 0.4949],
#         [ 0.3825],
#         ...,
#         [-0.0196],
#         [-0.0561],
#         [-0.0576]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5217],
#         [ 0.4934],
#         [ 0.3809],
#         ...,
#         [-0.0193],
#         [-0.0556],
#         [-0.0570]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0047, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0053, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.5200],
#         [ 0.4917],
#         [ 0.3792],
#         ...,
#         [-0.0191],
#         [-0.0551],
#         [-0.0565]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5183],
#         [ 0.4898],
#         [ 0.3774],
#         ...,
#         [-0.0190],
#         [-0.0547],
#         [-0.0561]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5163],
#         [ 0.4878],
#         [ 0.3753],
#         ...,
#         [-0.0190],
#         [-0.0544],
#         [-0.0558]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5142],
#         [ 0.4857],
#         [ 0.3732],
#         ...,
#         [-0.0191],
#         [-0.0542],
#         [-0.0555]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5121],
#         [ 0.4834],
#         [ 0.3710],
#         ...,
#         [-0.0192],
#         [-0.0540],
#         [-0.0553]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5098],
#         [ 0.4811],
#         [ 0.3686],
#         ...,
#         [-0.0193],
#         [-0.0539],
#         [-0.0552]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5075],
#         [ 0.4787],
#         [ 0.3663],
#         ...,
#         [-0.0195],
#         [-0.0538],
#         [-0.0550]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5051],
#         [ 0.4763],
#         [ 0.3639],
#         ...,
#         [-0.0197],
#         [-0.0537],
#         [-0.0549]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5028],
#         [ 0.4739],
#         [ 0.3615],
#         ...,
#         [-0.0199],
#         [-0.0536],
#         [-0.0548]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.5004],
#         [ 0.4715],
#         [ 0.3591],
#         ...,
#         [-0.0200],
#         [-0.0534],
#         [-0.0546]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0041, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.4981],
#         [ 0.4691],
#         [ 0.3568],
#         ...,
#         [-0.0202],
#         [-0.0533],
#         [-0.0544]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4959],
#         [ 0.4668],
#         [ 0.3546],
#         ...,
#         [-0.0202],
#         [-0.0531],
#         [-0.0542]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4937],
#         [ 0.4645],
#         [ 0.3524],
#         ...,
#         [-0.0202],
#         [-0.0528],
#         [-0.0539]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4916],
#         [ 0.4624],
#         [ 0.3503],
#         ...,
#         [-0.0202],
#         [-0.0525],
#         [-0.0536]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4895],
#         [ 0.4602],
#         [ 0.3483],
#         ...,
#         [-0.0201],
#         [-0.0521],
#         [-0.0532]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4875],
#         [ 0.4582],
#         [ 0.3463],
#         ...,
#         [-0.0200],
#         [-0.0517],
#         [-0.0527]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4855],
#         [ 0.4562],
#         [ 0.3444],
#         ...,
#         [-0.0198],
#         [-0.0513],
#         [-0.0523]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4836],
#         [ 0.4542],
#         [ 0.3426],
#         ...,
#         [-0.0196],
#         [-0.0508],
#         [-0.0518]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4817],
#         [ 0.4523],
#         [ 0.3408],
#         ...,
#         [-0.0193],
#         [-0.0503],
#         [-0.0513]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4798],
#         [ 0.4504],
#         [ 0.3390],
#         ...,
#         [-0.0191],
#         [-0.0498],
#         [-0.0507]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0036, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0042, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.4779],
#         [ 0.4484],
#         [ 0.3372],
#         ...,
#         [-0.0188],
#         [-0.0493],
#         [-0.0502]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4760],
#         [ 0.4465],
#         [ 0.3353],
#         ...,
#         [-0.0185],
#         [-0.0488],
#         [-0.0497]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4741],
#         [ 0.4445],
#         [ 0.3335],
#         ...,
#         [-0.0183],
#         [-0.0483],
#         [-0.0491]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4720],
#         [ 0.4425],
#         [ 0.3316],
#         ...,
#         [-0.0180],
#         [-0.0478],
#         [-0.0486]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4700],
#         [ 0.4404],
#         [ 0.3297],
#         ...,
#         [-0.0178],
#         [-0.0473],
#         [-0.0481]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4678],
#         [ 0.4382],
#         [ 0.3277],
#         ...,
#         [-0.0176],
#         [-0.0469],
#         [-0.0477]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4656],
#         [ 0.4360],
#         [ 0.3257],
#         ...,
#         [-0.0174],
#         [-0.0465],
#         [-0.0472]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4634],
#         [ 0.4337],
#         [ 0.3236],
#         ...,
#         [-0.0173],
#         [-0.0461],
#         [-0.0468]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4610],
#         [ 0.4313],
#         [ 0.3215],
#         ...,
#         [-0.0171],
#         [-0.0457],
#         [-0.0464]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4586],
#         [ 0.4289],
#         [ 0.3193],
#         ...,
#         [-0.0171],
#         [-0.0453],
#         [-0.0460]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0031, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0037, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.4561],
#         [ 0.4264],
#         [ 0.3170],
#         ...,
#         [-0.0170],
#         [-0.0450],
#         [-0.0457]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4536],
#         [ 0.4239],
#         [ 0.3147],
#         ...,
#         [-0.0169],
#         [-0.0447],
#         [-0.0453]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4511],
#         [ 0.4213],
#         [ 0.3124],
#         ...,
#         [-0.0168],
#         [-0.0444],
#         [-0.0450]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4485],
#         [ 0.4187],
#         [ 0.3101],
#         ...,
#         [-0.0168],
#         [-0.0441],
#         [-0.0446]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4458],
#         [ 0.4161],
#         [ 0.3078],
#         ...,
#         [-0.0167],
#         [-0.0437],
#         [-0.0443]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4432],
#         [ 0.4135],
#         [ 0.3054],
#         ...,
#         [-0.0167],
#         [-0.0434],
#         [-0.0440]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4405],
#         [ 0.4108],
#         [ 0.3031],
#         ...,
#         [-0.0166],
#         [-0.0431],
#         [-0.0436]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4378],
#         [ 0.4081],
#         [ 0.3008],
#         ...,
#         [-0.0165],
#         [-0.0428],
#         [-0.0433]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4351],
#         [ 0.4055],
#         [ 0.2984],
#         ...,
#         [-0.0164],
#         [-0.0424],
#         [-0.0429]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4324],
#         [ 0.4028],
#         [ 0.2961],
#         ...,
#         [-0.0163],
#         [-0.0421],
#         [-0.0425]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0026, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0032, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.4298],
#         [ 0.4002],
#         [ 0.2938],
#         ...,
#         [-0.0162],
#         [-0.0417],
#         [-0.0421]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4271],
#         [ 0.3975],
#         [ 0.2915],
#         ...,
#         [-0.0161],
#         [-0.0413],
#         [-0.0417]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4243],
#         [ 0.3948],
#         [ 0.2893],
#         ...,
#         [-0.0159],
#         [-0.0409],
#         [-0.0413]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4216],
#         [ 0.3922],
#         [ 0.2870],
#         ...,
#         [-0.0157],
#         [-0.0405],
#         [-0.0409]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4189],
#         [ 0.3895],
#         [ 0.2847],
#         ...,
#         [-0.0156],
#         [-0.0401],
#         [-0.0404]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4161],
#         [ 0.3868],
#         [ 0.2825],
#         ...,
#         [-0.0154],
#         [-0.0397],
#         [-0.0400]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4134],
#         [ 0.3840],
#         [ 0.2802],
#         ...,
#         [-0.0152],
#         [-0.0393],
#         [-0.0395]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4106],
#         [ 0.3813],
#         [ 0.2779],
#         ...,
#         [-0.0150],
#         [-0.0389],
#         [-0.0391]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4077],
#         [ 0.3785],
#         [ 0.2756],
#         ...,
#         [-0.0149],
#         [-0.0384],
#         [-0.0387]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.4048],
#         [ 0.3757],
#         [ 0.2733],
#         ...,
#         [-0.0147],
#         [-0.0380],
#         [-0.0382]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0022, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0027, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.4019],
#         [ 0.3729],
#         [ 0.2709],
#         ...,
#         [-0.0145],
#         [-0.0376],
#         [-0.0378]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3989],
#         [ 0.3700],
#         [ 0.2685],
#         ...,
#         [-0.0144],
#         [-0.0372],
#         [-0.0374]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3959],
#         [ 0.3671],
#         [ 0.2662],
#         ...,
#         [-0.0142],
#         [-0.0368],
#         [-0.0370]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3929],
#         [ 0.3641],
#         [ 0.2637],
#         ...,
#         [-0.0141],
#         [-0.0364],
#         [-0.0366]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3898],
#         [ 0.3611],
#         [ 0.2613],
#         ...,
#         [-0.0139],
#         [-0.0361],
#         [-0.0362]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3866],
#         [ 0.3580],
#         [ 0.2588],
#         ...,
#         [-0.0138],
#         [-0.0357],
#         [-0.0358]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3834],
#         [ 0.3550],
#         [ 0.2564],
#         ...,
#         [-0.0136],
#         [-0.0353],
#         [-0.0354]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3802],
#         [ 0.3519],
#         [ 0.2539],
#         ...,
#         [-0.0135],
#         [-0.0350],
#         [-0.0350]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3769],
#         [ 0.3487],
#         [ 0.2514],
#         ...,
#         [-0.0134],
#         [-0.0346],
#         [-0.0346]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3736],
#         [ 0.3456],
#         [ 0.2488],
#         ...,
#         [-0.0133],
#         [-0.0342],
#         [-0.0342]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0023, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.3703],
#         [ 0.3424],
#         [ 0.2463],
#         ...,
#         [-0.0131],
#         [-0.0339],
#         [-0.0338]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3670],
#         [ 0.3392],
#         [ 0.2438],
#         ...,
#         [-0.0130],
#         [-0.0335],
#         [-0.0335]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3636],
#         [ 0.3359],
#         [ 0.2413],
#         ...,
#         [-0.0129],
#         [-0.0331],
#         [-0.0331]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3602],
#         [ 0.3327],
#         [ 0.2387],
#         ...,
#         [-0.0127],
#         [-0.0328],
#         [-0.0327]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3568],
#         [ 0.3294],
#         [ 0.2362],
#         ...,
#         [-0.0126],
#         [-0.0324],
#         [-0.0323]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3534],
#         [ 0.3262],
#         [ 0.2337],
#         ...,
#         [-0.0125],
#         [-0.0320],
#         [-0.0319]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3499],
#         [ 0.3229],
#         [ 0.2311],
#         ...,
#         [-0.0123],
#         [-0.0317],
#         [-0.0315]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3465],
#         [ 0.3196],
#         [ 0.2286],
#         ...,
#         [-0.0122],
#         [-0.0313],
#         [-0.0311]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3430],
#         [ 0.3163],
#         [ 0.2260],
#         ...,
#         [-0.0120],
#         [-0.0309],
#         [-0.0307]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3395],
#         [ 0.3129],
#         [ 0.2235],
#         ...,
#         [-0.0118],
#         [-0.0305],
#         [-0.0303]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0014, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0018, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.3359],
#         [ 0.3096],
#         [ 0.2210],
#         ...,
#         [-0.0117],
#         [-0.0301],
#         [-0.0299]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3324],
#         [ 0.3063],
#         [ 0.2184],
#         ...,
#         [-0.0115],
#         [-0.0297],
#         [-0.0295]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3288],
#         [ 0.3029],
#         [ 0.2159],
#         ...,
#         [-0.0114],
#         [-0.0293],
#         [-0.0291]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3252],
#         [ 0.2995],
#         [ 0.2133],
#         ...,
#         [-0.0112],
#         [-0.0290],
#         [-0.0287]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3216],
#         [ 0.2961],
#         [ 0.2108],
#         ...,
#         [-0.0110],
#         [-0.0286],
#         [-0.0283]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3180],
#         [ 0.2927],
#         [ 0.2082],
#         ...,
#         [-0.0109],
#         [-0.0282],
#         [-0.0279]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3143],
#         [ 0.2892],
#         [ 0.2057],
#         ...,
#         [-0.0107],
#         [-0.0278],
#         [-0.0275]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3106],
#         [ 0.2857],
#         [ 0.2031],
#         ...,
#         [-0.0106],
#         [-0.0275],
#         [-0.0271]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3069],
#         [ 0.2823],
#         [ 0.2005],
#         ...,
#         [-0.0104],
#         [-0.0271],
#         [-0.0267]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.3032],
#         [ 0.2788],
#         [ 0.1979],
#         ...,
#         [-0.0103],
#         [-0.0267],
#         [-0.0263]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0015, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.2994],
#         [ 0.2753],
#         [ 0.1954],
#         ...,
#         [-0.0101],
#         [-0.0263],
#         [-0.0259]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2957],
#         [ 0.2717],
#         [ 0.1928],
#         ...,
#         [-0.0100],
#         [-0.0260],
#         [-0.0256]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2919],
#         [ 0.2682],
#         [ 0.1902],
#         ...,
#         [-0.0098],
#         [-0.0256],
#         [-0.0252]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2881],
#         [ 0.2646],
#         [ 0.1876],
#         ...,
#         [-0.0097],
#         [-0.0253],
#         [-0.0248]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2843],
#         [ 0.2611],
#         [ 0.1850],
#         ...,
#         [-0.0095],
#         [-0.0249],
#         [-0.0244]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2804],
#         [ 0.2575],
#         [ 0.1824],
#         ...,
#         [-0.0094],
#         [-0.0246],
#         [-0.0240]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2766],
#         [ 0.2540],
#         [ 0.1799],
#         ...,
#         [-0.0093],
#         [-0.0242],
#         [-0.0237]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2728],
#         [ 0.2504],
#         [ 0.1773],
#         ...,
#         [-0.0091],
#         [-0.0238],
#         [-0.0233]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2689],
#         [ 0.2468],
#         [ 0.1747],
#         ...,
#         [-0.0090],
#         [-0.0235],
#         [-0.0229]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2651],
#         [ 0.2433],
#         [ 0.1722],
#         ...,
#         [-0.0088],
#         [-0.0231],
#         [-0.0226]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0008, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0011, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.2613],
#         [ 0.2397],
#         [ 0.1696],
#         ...,
#         [-0.0087],
#         [-0.0228],
#         [-0.0222]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2574],
#         [ 0.2361],
#         [ 0.1671],
#         ...,
#         [-0.0085],
#         [-0.0224],
#         [-0.0218]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2536],
#         [ 0.2326],
#         [ 0.1646],
#         ...,
#         [-0.0084],
#         [-0.0221],
#         [-0.0214]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2497],
#         [ 0.2290],
#         [ 0.1620],
#         ...,
#         [-0.0082],
#         [-0.0217],
#         [-0.0211]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2459],
#         [ 0.2255],
#         [ 0.1595],
#         ...,
#         [-0.0081],
#         [-0.0214],
#         [-0.0207]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2421],
#         [ 0.2219],
#         [ 0.1570],
#         ...,
#         [-0.0079],
#         [-0.0210],
#         [-0.0203]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2382],
#         [ 0.2184],
#         [ 0.1545],
#         ...,
#         [-0.0078],
#         [-0.0207],
#         [-0.0200]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2344],
#         [ 0.2149],
#         [ 0.1520],
#         ...,
#         [-0.0076],
#         [-0.0203],
#         [-0.0196]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2306],
#         [ 0.2113],
#         [ 0.1496],
#         ...,
#         [-0.0075],
#         [-0.0200],
#         [-0.0193]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2268],
#         [ 0.2078],
#         [ 0.1471],
#         ...,
#         [-0.0073],
#         [-0.0196],
#         [-0.0189]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(0.0006, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(0.0009, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.2230],
#         [ 0.2043],
#         [ 0.1447],
#         ...,
#         [-0.0072],
#         [-0.0193],
#         [-0.0186]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2192],
#         [ 0.2008],
#         [ 0.1422],
#         ...,
#         [-0.0070],
#         [-0.0190],
#         [-0.0182]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2154],
#         [ 0.1973],
#         [ 0.1398],
#         ...,
#         [-0.0069],
#         [-0.0186],
#         [-0.0179]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2116],
#         [ 0.1939],
#         [ 0.1374],
#         ...,
#         [-0.0067],
#         [-0.0183],
#         [-0.0175]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2079],
#         [ 0.1904],
#         [ 0.1350],
#         ...,
#         [-0.0066],
#         [-0.0180],
#         [-0.0172]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.2041],
#         [ 0.1870],
#         [ 0.1326],
#         ...,
#         [-0.0065],
#         [-0.0177],
#         [-0.0168]], device='cuda:0', grad_fn=<IndexBackward0>)
# ...
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0180],
#         [ 0.0172],
#         [ 0.0176],
#         ...,
#         [ 0.0002],
#         [-0.0021],
#         [-0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0171],
#         [ 0.0163],
#         [ 0.0170],
#         ...,
#         [ 0.0003],
#         [-0.0020],
#         [-0.0008]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0161],
#         [ 0.0155],
#         [ 0.0164],
#         ...,
#         [ 0.0003],
#         [-0.0019],
#         [-0.0007]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0152],
#         [ 0.0146],
#         [ 0.0158],
#         ...,
#         [ 0.0003],
#         [-0.0019],
#         [-0.0006]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0143],
#         [ 0.0138],
#         [ 0.0153],
#         ...,
#         [ 0.0003],
#         [-0.0018],
#         [-0.0005]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0134],
#         [ 0.0130],
#         [ 0.0147],
#         ...,
#         [ 0.0004],
#         [-0.0017],
#         [-0.0005]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0125],
#         [ 0.0122],
#         [ 0.0142],
#         ...,
#         [ 0.0004],
#         [-0.0016],
#         [-0.0004]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0117],
#         [ 0.0115],
#         [ 0.0137],
#         ...,
#         [ 0.0004],
#         [-0.0016],
#         [-0.0003]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.9139e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(5.3500e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.0109],
#         [ 0.0108],
#         [ 0.0132],
#         ...,
#         [ 0.0004],
#         [-0.0015],
#         [-0.0003]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0101],
#         [ 0.0101],
#         [ 0.0127],
#         ...,
#         [ 0.0004],
#         [-0.0014],
#         [-0.0002]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0094],
#         [ 0.0094],
#         [ 0.0123],
#         ...,
#         [ 0.0005],
#         [-0.0014],
#         [-0.0001]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 8.6571e-03],
#         [ 8.7043e-03],
#         [ 1.1827e-02],
#         ...,
#         [ 4.8858e-04],
#         [-1.3222e-03],
#         [-8.0526e-05]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 7.9474e-03],
#         [ 8.0613e-03],
#         [ 1.1395e-02],
#         ...,
#         [ 5.0670e-04],
#         [-1.2627e-03],
#         [-2.2858e-05]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 7.2595e-03],
#         [ 7.4383e-03],
#         [ 1.0976e-02],
#         ...,
#         [ 5.2395e-04],
#         [-1.2049e-03],
#         [ 3.2932e-05]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 6.5925e-03],
#         [ 6.8344e-03],
#         [ 1.0570e-02],
#         ...,
#         [ 5.4029e-04],
#         [-1.1490e-03],
#         [ 8.6874e-05]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0059],
#         [ 0.0062],
#         [ 0.0102],
#         ...,
#         [ 0.0006],
#         [-0.0011],
#         [ 0.0001]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0053],
#         [ 0.0057],
#         [ 0.0098],
#         ...,
#         [ 0.0006],
#         [-0.0010],
#         [ 0.0002]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0047],
#         [ 0.0051],
#         [ 0.0094],
#         ...,
#         [ 0.0006],
#         [-0.0010],
#         [ 0.0002]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.6190e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(4.6162e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[ 0.0041],
#         [ 0.0046],
#         [ 0.0091],
#         ...,
#         [ 0.0006],
#         [-0.0009],
#         [ 0.0003]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0036],
#         [ 0.0041],
#         [ 0.0087],
#         ...,
#         [ 0.0006],
#         [-0.0009],
#         [ 0.0003]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0030],
#         [ 0.0036],
#         [ 0.0084],
#         ...,
#         [ 0.0006],
#         [-0.0008],
#         [ 0.0004]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0025],
#         [ 0.0031],
#         [ 0.0081],
#         ...,
#         [ 0.0006],
#         [-0.0008],
#         [ 0.0004]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0020],
#         [ 0.0026],
#         [ 0.0078],
#         ...,
#         [ 0.0006],
#         [-0.0008],
#         [ 0.0005]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0015],
#         [ 0.0022],
#         [ 0.0074],
#         ...,
#         [ 0.0007],
#         [-0.0007],
#         [ 0.0005]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0010],
#         [ 0.0018],
#         [ 0.0072],
#         ...,
#         [ 0.0007],
#         [-0.0007],
#         [ 0.0005]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 0.0005],
#         [ 0.0013],
#         [ 0.0069],
#         ...,
#         [ 0.0007],
#         [-0.0006],
#         [ 0.0006]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[ 6.0618e-05],
#         [ 9.2956e-04],
#         [ 6.5994e-03],
#         ...,
#         [ 6.7717e-04],
#         [-5.9915e-04],
#         [ 6.0907e-04]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0004],
#         [ 0.0005],
#         [ 0.0063],
#         ...,
#         [ 0.0007],
#         [-0.0006],
#         [ 0.0006]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.4597e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(4.1464e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[-0.0008],
#         [ 0.0002],
#         [ 0.0061],
#         ...,
#         [ 0.0007],
#         [-0.0005],
#         [ 0.0007]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0012],
#         [-0.0002],
#         [ 0.0058],
#         ...,
#         [ 0.0007],
#         [-0.0005],
#         [ 0.0007]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0016],
#         [-0.0006],
#         [ 0.0056],
#         ...,
#         [ 0.0007],
#         [-0.0005],
#         [ 0.0007]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0020],
#         [-0.0009],
#         [ 0.0054],
#         ...,
#         [ 0.0007],
#         [-0.0004],
#         [ 0.0008]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0023],
#         [-0.0012],
#         [ 0.0051],
#         ...,
#         [ 0.0007],
#         [-0.0004],
#         [ 0.0008]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0027],
#         [-0.0016],
#         [ 0.0049],
#         ...,
#         [ 0.0007],
#         [-0.0004],
#         [ 0.0008]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0030],
#         [-0.0019],
#         [ 0.0047],
#         ...,
#         [ 0.0007],
#         [-0.0003],
#         [ 0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0034],
#         [-0.0022],
#         [ 0.0045],
#         ...,
#         [ 0.0007],
#         [-0.0003],
#         [ 0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0037],
#         [-0.0024],
#         [ 0.0043],
#         ...,
#         [ 0.0007],
#         [-0.0003],
#         [ 0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0040],
#         [-0.0027],
#         [ 0.0041],
#         ...,
#         [ 0.0007],
#         [-0.0003],
#         [ 0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.3712e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(3.8389e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[-0.0043],
#         [-0.0030],
#         [ 0.0040],
#         ...,
#         [ 0.0007],
#         [-0.0002],
#         [ 0.0009]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0046],
#         [-0.0032],
#         [ 0.0038],
#         ...,
#         [ 0.0007],
#         [-0.0002],
#         [ 0.0010]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0049],
#         [-0.0035],
#         [ 0.0036],
#         ...,
#         [ 0.0007],
#         [-0.0002],
#         [ 0.0010]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0051],
#         [-0.0037],
#         [ 0.0035],
#         ...,
#         [ 0.0007],
#         [-0.0002],
#         [ 0.0010]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0054],
#         [-0.0040],
#         [ 0.0033],
#         ...,
#         [ 0.0007],
#         [-0.0001],
#         [ 0.0010]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0056],
#         [-0.0042],
#         [ 0.0032],
#         ...,
#         [ 0.0007],
#         [-0.0001],
#         [ 0.0010]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-5.8559e-03],
#         [-4.3886e-03],
#         [ 3.0265e-03],
#         ...,
#         [ 7.2792e-04],
#         [-9.8556e-05],
#         [ 1.0622e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-6.0845e-03],
#         [-4.5930e-03],
#         [ 2.8895e-03],
#         ...,
#         [ 7.2694e-04],
#         [-7.9095e-05],
#         [ 1.0790e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-6.3047e-03],
#         [-4.7896e-03],
#         [ 2.7576e-03],
#         ...,
#         [ 7.2563e-04],
#         [-6.0350e-05],
#         [ 1.0951e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-6.5168e-03],
#         [-4.9789e-03],
#         [ 2.6307e-03],
#         ...,
#         [ 7.2399e-04],
#         [-4.2349e-05],
#         [ 1.1104e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.3184e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(3.6310e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[-6.7210e-03],
#         [-5.1610e-03],
#         [ 2.5085e-03],
#         ...,
#         [ 7.2208e-04],
#         [-2.5004e-05],
#         [ 1.1251e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-6.9175e-03],
#         [-5.3362e-03],
#         [ 2.3911e-03],
#         ...,
#         [ 7.1990e-04],
#         [-8.2552e-06],
#         [ 1.1392e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.1067e-03],
#         [-5.5045e-03],
#         [ 2.2782e-03],
#         ...,
#         [ 7.1743e-04],
#         [ 7.8380e-06],
#         [ 1.1527e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.2888e-03],
#         [-5.6666e-03],
#         [ 2.1697e-03],
#         ...,
#         [ 7.1472e-04],
#         [ 2.3305e-05],
#         [ 1.1656e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.4640e-03],
#         [-5.8222e-03],
#         [ 2.0654e-03],
#         ...,
#         [ 7.1177e-04],
#         [ 3.8236e-05],
#         [ 1.1779e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.6325e-03],
#         [-5.9718e-03],
#         [ 1.9653e-03],
#         ...,
#         [ 7.0858e-04],
#         [ 5.2541e-05],
#         [ 1.1896e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.7946e-03],
#         [-6.1156e-03],
#         [ 1.8690e-03],
#         ...,
#         [ 7.0518e-04],
#         [ 6.6370e-05],
#         [ 1.2008e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-7.9504e-03],
#         [-6.2538e-03],
#         [ 1.7765e-03],
#         ...,
#         [ 7.0155e-04],
#         [ 7.9632e-05],
#         [ 1.2115e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-8.1003e-03],
#         [-6.3865e-03],
#         [ 1.6877e-03],
#         ...,
#         [ 6.9770e-04],
#         [ 9.2387e-05],
#         [ 1.2217e-03]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0082],
#         [-0.0065],
#         [ 0.0016],
#         ...,
#         [ 0.0007],
#         [ 0.0001],
#         [ 0.0012]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor(1.2833e-05, device='cuda:0', grad_fn=<MseLossBackward0>) tensor(3.4849e-05, device='cuda:0', grad_fn=<MseLossBackward0>)
# tensor([[-0.0084],
#         [-0.0066],
#         [ 0.0015],
#         ...,
#         [ 0.0007],
#         [ 0.0001],
#         [ 0.0012]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0085],
#         [-0.0068],
#         [ 0.0014],
#         ...,
#         [ 0.0007],
#         [ 0.0001],
#         [ 0.0012]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0086],
#         [-0.0069],
#         [ 0.0014],
#         ...,
#         [ 0.0007],
#         [ 0.0001],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0088],
#         [-0.0070],
#         [ 0.0013],
#         ...,
#         [ 0.0007],
#         [ 0.0001],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0089],
#         [-0.0071],
#         [ 0.0012],
#         ...,
#         [ 0.0007],
#         [ 0.0002],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0090],
#         [-0.0072],
#         [ 0.0012],
#         ...,
#         [ 0.0007],
#         [ 0.0002],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0091],
#         [-0.0073],
#         [ 0.0011],
#         ...,
#         [ 0.0007],
#         [ 0.0002],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0092],
#         [-0.0074],
#         [ 0.0010],
#         ...,
#         [ 0.0007],
#         [ 0.0002],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])
# tensor([[-0.0093],
#         [-0.0075],
#         [ 0.0010],
#         ...,
#         [ 0.0006],
#         [ 0.0002],
#         [ 0.0013]], device='cuda:0', grad_fn=<IndexBackward0>)
# torch.Size([4480, 1])
# True
# torch.Size([4480, 1])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
class DRBC(nn.Module):
    def __init__(self, embedding_size, initialization_stddev, reg_hidden):
        super().__init__()
        self.embedding_size = embedding_size
        self.initialization_stddev = initialization_stddev
        self.reg_hidden = reg_hidden
        self.w0 = nn.Parameter(torch.randn(3, self.embedding_size) * self.initialization_stddev)
        self.w1 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.w2 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.w3 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.u1 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.u2 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.u3 = nn.Parameter(torch.randn(self.embedding_size, self.embedding_size) * self.initialization_stddev)
        self.w4 = nn.Parameter(torch.randn(self.embedding_size, self.reg_hidden) * self.initialization_stddev)
        self.w5 = nn.Parameter(torch.randn(self.reg_hidden, 1) * self.initialization_stddev)
        
    def forward(self, x, edge_index):
        deg = degree(edge_index[0]).cuda()
        deg = torch.reshape(deg,(-1,1))
        G = nx.Graph() 
        G.add_edges_from(np.transpose(edge_index.cpu().numpy()))
        neighbours = [list(G.neighbors(i)) for i in range(deg.shape[0])]
        ones = torch.reshape(torch.ones(deg.shape),(-1,1)).cuda()
        h0 = torch.cat((deg, ones, ones), 1)
        h1 = F.relu(torch.matmul(h0,self.w0))
        h1 = F.normalize(h1, p=2, dim=1)
        hn2=torch.empty(0,self.embedding_size).cuda()
        for (i,nei) in enumerate(neighbours):
            summation=0
            for j in nei:
                summation+=1/(torch.sqrt(deg[i]+1)*torch.sqrt(deg[j]+1))*h1[j]
            hn2=torch.cat((hn2,summation.reshape(1,-1)),0)
        update_gate = torch.sigmoid(torch.matmul(hn2,self.w1) + torch.matmul(h1,self.u1))
        reset_gate = torch.sigmoid(torch.matmul(hn2,self.w2) + torch.matmul(h1,self.u2))
        future = torch.tanh(torch.matmul(hn2,self.w3) + torch.matmul((reset_gate*h1),self.u3))
        h2 = update_gate * future + (1 - update_gate) * h1
        h2 = F.normalize(h2, p=2, dim=1)
        hn3=torch.empty(0,self.embedding_size).cuda()
        for (i,nei) in enumerate(neighbours):
            summation=0
            for j in nei:
                summation+=1/(torch.sqrt(deg[i]+1)*torch.sqrt(deg[j]+1))*h2[j]
            hn3=torch.cat((h2,summation.reshape(1,-1)),0)
        hn3=hn3[1:,:]
        update_gate = torch.sigmoid(torch.matmul(hn3,self.w1) + torch.matmul(h2,self.u1))
        reset_gate = torch.sigmoid(torch.matmul(hn3,self.w2) + torch.matmul(h2,self.u2))
        future = torch.tanh(torch.matmul(hn3,self.w3) + torch.matmul((reset_gate*h2),self.u3))
        h3 = update_gate * future + (1 - update_gate) * h2
        h3 = F.normalize(h3, p=2, dim=1)
        hs=torch.stack((h1,h2,h3),dim=2)
        z=torch.max((hs),dim=2)
        hidden = torch.relu(torch.matmul(z.values,self.w4))
        betw_pred = torch.matmul(hidden, self.w5)
        return betw_pred

model = DRBC(embedding_size=64, initialization_stddev=0.01, reg_hidden=32)
model.to(device)
# Out:
# DRBC()

# %%
import random
def criterion(predicteddiff,targetdiff):
    loss = -(torch.sigmoid(targetdiff))*torch.log(torch.sigmoid(predicteddiff))-(1-torch.sigmoid(targetdiff))*torch.log(1-torch.sigmoid(predicteddiff))
    return torch.sum(loss)

def get_samples(n):
    list1=[]
    list2=[]
    for i in range(n*5):
        num1 = random.randint(0, n-1)
        num2 = random.randint(0, n-1)
        while num1 == num2:
            num2 = random.randint(0, n-1)
        list1.append(num1)    
        list2.append(num2)
    return list1, list2
#criterion = torch.nn.MSELoss()  # Define loss criterion.

# %%
torch.matmul((data.y[list1]-data.y[list2]),(out[list1]-out[list2]))
# Out:
# tensor([-0.0004], device='cuda:0', grad_fn=<SqueezeBackward3>)

# %%
torch.cuda.empty_cache()
n=5000
list1=[]
list2=[]
for i in range(n*1):
    num1 = random.randint(0, n-1)
    num2 = random.randint(0, n-1)
    while num1 == num2:
        num2 = random.randint(0, n-1)
    list1.append(num1)    
    list2.append(num2)

sam=(out[list1]-out[list2])
ple=(data.y[list1]-data.y[list2])
print(max(sam),min(sam),max(ple),min(ple))
# Out:
# tensor([0.0002], device='cuda:0', grad_fn=<UnbindBackward0>) tensor([-0.0002], device='cuda:0', grad_fn=<UnbindBackward0>) tensor(0.0941, device='cuda:0') tensor(-0.0927, device='cuda:0')

# %%
optimizer = torch.optim.Adam(model.parameters(),lr=0.001)  # Define optimizer.

def train(data):
    optimizer.zero_grad()  # Clear gradients.
    out = model(data.x, data.edge_index)  # Perform a single forward pass.
    list1,list2 = get_samples(data.x.shape[0])
    print(model.w0)
    print(out)
    loss = criterion((out[list1]-out[list2]), (data.y[list1]-data.y[list2]).reshape(-1,1))  # Compute the loss solely based on the training nodes.
    loss.backward()  # Derive gradients.
    optimizer.step()  # Update parameters based on gradients.
    return loss

for epoch in range(350):
    data = data.to('cuda:0')
    loss = train(data)
    print(loss)
# Out:
# Parameter containing:
# tensor([[ 0.0121, -0.0113, -0.0185, -0.0160,  0.0209,  0.0143, -0.0297, -0.0098,
#           0.0336, -0.0085,  0.0299,  0.0584, -0.0093, -0.0251, -0.0076, -0.0244,
#          -0.0044,  0.0149, -0.0046, -0.0199,  0.0418,  0.0518,  0.0091, -0.0284,
#          -0.0119,  0.0122, -0.0219, -0.0020,  0.0253,  0.0127, -0.0324,  0.0378,
#           0.0287,  0.0274,  0.0377, -0.0028, -0.0073,  0.0181, -0.0176, -0.0259,
#          -0.0169, -0.0007, -0.0047,  0.0249, -0.0048, -0.0147, -0.0026, -0.0139,
#          -0.0171,  0.0282, -0.0071, -0.0135, -0.0122, -0.0163, -0.0052,  0.0243,
#          -0.0254,  0.0228, -0.0186,  0.0027,  0.0171, -0.0020,  0.0186,  0.0273],
#         [ 0.0286, -0.0087, -0.0277,  0.0125,  0.0283,  0.0106, -0.0178,  0.0131,
#           0.0263, -0.0132,  0.0012, -0.0025, -0.0098, -0.0223, -0.0011,  0.0301,
#           0.0025,  0.0026, -0.0022,  0.0108, -0.0060, -0.0202,  0.0153, -0.0223,
#          -0.0040, -0.0236,  0.0063,  0.0073, -0.0035,  0.0149, -0.0042,  0.0190,
#           0.0296,  0.0191,  0.0131,  0.0049,  0.0025, -0.0154, -0.0376,  0.0322,
#           0.0012, -0.0453,  0.0019,  0.0177,  0.0062, -0.0083, -0.0132, -0.0017,
#          -0.0112,  0.0138,  0.0034, -0.0004,  0.0048,  0.0101, -0.0189,  0.0215,
#           0.0271,  0.0208, -0.0340,  0.0256,  0.0167, -0.0181,  0.0110,  0.0338],
#         [ 0.0256, -0.0108, -0.0234,  0.0109,  0.0185,  0.0082, -0.0178, -0.0180,
#           0.0178,  0.0159,  0.0092, -0.0141, -0.0039, -0.0431, -0.0064,  0.0258,
#           0.0052,  0.0363, -0.0080,  0.0064, -0.0139, -0.0142,  0.0226, -0.0183,
#           0.0066, -0.0071,  0.0046,  0.0001, -0.0154,  0.0138, -0.0030,  0.0162,
#           0.0026,  0.0294,  0.0282, -0.0038,  0.0046, -0.0028, -0.0307,  0.0290,
#          -0.0374, -0.0290,  0.0098,  0.0060, -0.0082, -0.0107, -0.0097, -0.0159,
#           0.0075,  0.0130, -0.0051, -0.0076, -0.0137,  0.0205,  0.0159, -0.0022,
#           0.0374, -0.0027, -0.0410,  0.0091,  0.0048, -0.0035,  0.0149,  0.0234]],
#        device='cuda:0', requires_grad=True)
# tensor([[0.0055],
#         [0.0054],
#         [0.0053],
#         ...,
#         [0.0028],
#         [0.0026],
#         [0.0019]], device='cuda:0', grad_fn=<MmBackward0>)
# tensor(17328.6758, device='cuda:0', grad_fn=<SumBackward0>)
# Parameter containing:
# tensor([[ 0.0131, -0.0113, -0.0185, -0.0160,  0.0199,  0.0133, -0.0297, -0.0098,
#           0.0326, -0.0085,  0.0289,  0.0594, -0.0093, -0.0251, -0.0076, -0.0244,
#          -0.0044,  0.0159, -0.0046, -0.0199,  0.0428,  0.0508,  0.0101, -0.0284,
#          -0.0119,  0.0132, -0.0219, -0.0020,  0.0243,  0.0117, -0.0324,  0.0368,
#           0.0277,  0.0264,  0.0367, -0.0028, -0.0073,  0.0191, -0.0176, -0.0259,
#          -0.0169, -0.0007, -0.0047,  0.0259, -0.0048, -0.0147, -0.0026, -0.0139,
#          -0.0171,  0.0272, -0.0071, -0.0135, -0.0122, -0.0163, -0.0052,  0.0233,
#          -0.0254,  0.0218, -0.0186,  0.0037,  0.0181, -0.0020,  0.0196,  0.0283],
#         [ 0.0296, -0.0087, -0.0277,  0.0125,  0.0293,  0.0096, -0.0178,  0.0131,
#           0.0273, -0.0132,  0.0002, -0.0035, -0.0098, -0.0223, -0.0011,  0.0301,
#           0.0025,  0.
], device='cuda:0', grad_fn=<MmBackward0>)
# tensor(17328.6523, device='cuda:0', grad_fn=<SumBackward0>)
# Parameter containing:
# tensor([[ 0.0236, -0.0113, -0.0185, -0.0160,  0.0224,  0.0001, -0.0297, -0.0098,
#           0.0323, -0.0085,  0.0158,  0.0613, -0.0093, -0.0251, -0.0076, -0.0244,
#          -0.0044,  0.0269, -0.0046, -0.0199,  0.0475,  0.0416,  0.0217, -0.0284,
#          -0.0119,  0.0251, -0.0219, -0.0020,  0.0248,  0.0152, -0.0324,  0.0477,
#           0.0213,  0.0255,  0.0330, -0.0028, -0.0073,  0.0319, -0.0176, -0.0259,
#          -0.0169, -0.0007, -0.0047,  0.0372, -0.0048, -0.0147, -0.0026, -0.0139,
#          -0.0171,  0.0223, -0.0071, -0.0135, -0.0122, -0.0163, -0.0052,  0.0140,
#          -0.0254,  0.0173, -0.0186, -0.0066,  0.0225, -0.0020,  0.0224,  0.0324],
#         [ 0.0346, -0.0087, -0.0277,  0.0125,  0.0315,  0.0115, -0.0178,  0.0131,
#           0.0322, -0.0132, -0.0072, -0.0027, -0.0098, -0.0223, -0.0011,  0.0301,
#           0.0025,  0.0073, -0.0022,  0.0108, -0.0064, -0.0218,  0.0169, -0.0223,
#          -0.0040, -0.0254,  0.0063,  0.0073, -0.0016,  0.0171, -0.0042,  0.0297,
#           0.0373,  0.0236,  0.0140,  0.0049,  0.0025, -0.0092, -0.0376,  0.0322,
#           0.0012, -0.0453,  0.0019,  0.0133,  0.0062, -0.0083, -0.0132, -0.0017,
#          -0.0112,  0.0102,  0.0034, -0.0004,  0.0048,  0.0101, -0.0189,  0.0229,
#           0.0271,  0.0223, -0.0340,  0.0160,  0.0155, -0.0181,  0.0130,  0.0337],
#         [ 0.0316, -0.0108, -0.0234,  0.0109,  0.0217,  0.0091, -0.0178, -0.0180,
#           0.0237,  0.0159,  0.0008, -0.0143, -0.0039, -0.0431, -0.0064,  0.0258,
#           0.0052,  0.0410, -0.0080,  0.0064, -0.0143, -0.0157,  0.0241, -0.0183,
#           0.0066, -0.0088,  0.0046,  0.0001, -0.0135,  0.0160, -0.0030,  0.0269,
#           0.0103,  0.0339,  0.0292, -0.0038,  0.0046,  0.0034, -0.0307,  0.0290,
#          -0.0374, -0.0290,  0.0098,  0.0016, -0.0082, -0.0107, -0.0097, -0.0159,
#           0.0075,  0.0094, -0.0051, -0.0076, -0.0137,  0.0205,  0.0159, -0.0009,
#           0.0374, -0.0012, -0.0410, -0.0004,  0.0036, -0.0035,  0.0169,  0.0234]],
#        device='cuda:0', requires_grad=True)
# tensor([[ 0.0245],
#         [ 0.0230],
#         [ 0.0211],
#         ...,
#         [ 0.0012],
#         [ 0.0009],
#         [-0.0003]], device='cuda:0', grad_fn=<MmBackward0>)
# tensor(17328.6426, device='cuda:0', grad_fn=<SumBackward0>)

# %%
    n=5000
    list1=[]
    list2=[]
    for i in range(n*5):
        num1 = random.randint(0, n-1)
        num2 = random.randint(0, n-1)
        while num1 == num2:
            num2 = random.randint(0, n-1)
        list1.append(num1)    
        list2.append(num2)

# %%
from torch_geometric.utils import degree
import torch.nn.functional as F
import torch.nn as nn
from torch_geometric.utils import to_networkx

# %%
embedding_size=128
initialization_stddev = 0.01

deg = degree(data.edge_index[0])
deg = torch.reshape(deg,(-1,1))
G = to_networkx(data)
neighbours = [list(G.neighbors(i)) for i in range(deg.shape[0])]
ones = torch.reshape(torch.ones(deg.shape),(-1,1))
h0 = torch.cat((deg, ones, ones), 1)
w0 = nn.Parameter(torch.randn(3, embedding_size) * initialization_stddev)
h1 = F.relu(torch.matmul(h0,w0))
h1 = F.normalize(h1, p=2, dim=1)

# %%
h1.shape
# Out:
# torch.Size([5000, 128])

# %%
hn2=torch.empty(0,embedding_size)
for (i,nei) in enumerate(neighbours):
    summation=0
    for j in nei:
        summation+=1/(torch.sqrt(deg[i]+1)*torch.sqrt(deg[j]+1))*h1[j]
    hn2=torch.cat((hn2,summation.reshape(1,-1)),0)

# %%
w1 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
w2 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
w3 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
u1 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
u2 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
u3 = nn.Parameter(torch.randn(embedding_size, embedding_size) * initialization_stddev)
update_gate = torch.sigmoid(torch.matmul(hn2,w1) + torch.matmul(h1,u1))
reset_gate = torch.sigmoid(torch.matmul(hn2,w2) + torch.matmul(h1,u2))
future = torch.tanh(torch.matmul(hn2,w3) + torch.matmul((reset_gate*h1),u3))

h2 = update_gate * future + (1 - update_gate) * h1
h2 = F.normalize(h2, p=2, dim=1)

# %%
hn3=torch.empty(0,embedding_size)
for (i,nei) in enumerate(neighbours):
    summation=0
    for j in nei:
        summation+=1/(torch.sqrt(deg[i]+1)*torch.sqrt(deg[j]+1))*h2[j]
    hn3=torch.cat((h2,summation.reshape(1,-1)),0)
hn3=hn3[1:,:]
update_gate = torch.sigmoid(torch.matmul(hn3,w1) + torch.matmul(h2,u1))
reset_gate = torch.sigmoid(torch.matmul(hn3,w2) + torch.matmul(h2,u2))
future = torch.tanh(torch.matmul(hn3,w3) + torch.matmul((reset_gate*h2),u3))

h3 = update_gate * future + (1 - update_gate) * h2
h3 = F.normalize(h3, p=2, dim=1)

# %%
hs=torch.stack((h1,h2,h3),dim=2)
z=torch.max((hs),dim=2)
z.values
# Out:
# tensor([[0.0061, 0.0000, 0.0549,  ..., 0.0000, 0.0000, 0.1235],
#         [0.0056, 0.0000, 0.0531,  ..., 0.0000, 0.0000, 0.1238],
#         [0.0040, 0.0000, 0.0387,  ..., 0.0000, 0.0000, 0.1239],
#         ...,
#         [0.0026, 0.0000, 0.0116,  ..., 0.0000, 0.0000, 0.1547],
#         [0.0026, 0.0000, 0.0110,  ..., 0.0000, 0.0000, 0.1547],
#         [0.0020, 0.0000, 0.0015,  ..., 0.0000, 0.0000, 0.1549]],
#        grad_fn=<MaxBackward0>)

# %%
reg_hidden = (int)(embedding_size / 2)
w4 = nn.Parameter(torch.randn(embedding_size, reg_hidden) * initialization_stddev)
w5 = nn.Parameter(torch.randn(reg_hidden, 1) * initialization_stddev)

# %%
hidden = torch.relu(torch.matmul(z.values,w4))
betw_pred = torch.matmul(hidden, w5)

# %%
betw_pred
# Out:
# tensor([[-2.0176e-04],
#         [-1.9122e-04],
#         [-1.1879e-04],
#         ...,
#         [-4.3495e-05],
#         [-4.0821e-05],
#         [ 7.5794e-06]], grad_fn=<MmBackward0>)

# %%
theone[:,1]
# Out:
# array([0., 1.])
